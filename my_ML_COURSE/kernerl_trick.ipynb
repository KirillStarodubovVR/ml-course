# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

import seaborn as sns

import sklearn as sk
from sklearn.datasets import make_classification
from sklearn.datasets import make_circles
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
x, y = make_circles(n_samples=1000, shuffle=True, noise=0.9, random_state=17)
x = preprocessing.scale(x)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=17)

print(X_train.shape, X_test.shape)
# Out:
# (500, 2) (500, 2)

# %%
y_train = np.where(y_train== 0,-1,1)
y_test = np.where(y_test==0,-1, 1)
np.bincount(y_train, y_test)
# Out:
# array([  0., 500.])

# %%
sns.scatterplot(X_train[:, 0], X_train[:, 1], hue=y_train.reshape(-1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 sns.scatterplot(X_train[:, 0], X_train[:, 1], hue=y_train.reshape(-1))
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
x, y = make_circles(n_samples = 1000, noise = 0.09)
x = preprocessing.scale(x)

# Разделение набора на тренировочную и тестовую части 
x_test = x[:500]
y_test = y[:500]
x = x[500:]
y = y[500:]

# Фильтруем точки по оси y – выбираем только равные [0, -1, 1]
y_train = np.where(y == -1,0,1)
y_test = np.where(y_test == [0, -1, 1])

data_train = pd.DataFrame({'X1': X_train[:,0], 'X2' : X_train[:,1], 'Y':y_train})
data_train
sns.scatterplot(data_train)
# Out:
# C:\Users\SKG\AppData\Local\Temp\ipykernel_7664\80598688.py:12: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   y_test = np.where(y_test == [0, -1, 1])
# <AxesSubplot: >
